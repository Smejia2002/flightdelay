# %% [markdown]
# # Auditoria de Dataset Pre-Entrenamiento
#
# ## Objetivo
# Evaluar si el dataset es confiable y usable antes de entrenar. No se entrena ningun modelo en esta fase.
#
# ## Dataset
# Ruta sugerida: ../DATASET ORIGINAL/DATASET_FINAL_HACKATHON_2026.parquet

# %%
import pandas as pd
from pathlib import Path

dataset_path = Path('..') / 'DATASET ORIGINAL' / 'DATASET_FINAL_HACKATHON_2026.parquet'
df = pd.read_parquet(dataset_path)
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK    FL_DATE OP_UNIQUE_CARRIER ORIGIN  \
# 0  2020      4             1            3 2020-04-01                9E    ATL
# 1  2020      4             1            3 2020-04-01                9E    DTW
# 2  2020      4             1            3 2020-04-01                9E    ATL
# 3  2020      4             1            3 2020-04-01                9E    RST
# 4  2020      4             1            3 2020-04-01                9E    DTW
#
#   ORIGIN_CITY_NAME DEST  DEST_CITY_NAME  ...  sched_minute_of_day  \
# 0      Atlanta, GA  CSG    Columbus, GA  ...                 1202
# 1      Detroit, MI  EVV  Evansville, IN  ...                 1226
# 2      Atlanta, GA  RST   Rochester, MN  ...                  832
# 3    Rochester, MN  ATL     Atlanta, GA  ...                  959
# 4      Detroit, MI  TYS   Knoxville, TN  ...                 1220
#
#       distance_bin   LATITUDE  LONGITUDE   STATION_KEY  DIST_MET_KM  TEMP  \
# 0  (10.999, 228.0]  33.636665 -84.428055  722190-13874     1.488682  15.0
# 1   (337.0, 438.0]  42.212502 -83.353333  725370-94847     2.759307   9.4
# 2   (674.0, 837.0]  33.636665 -84.428055  722190-13874     1.488682   7.2
# 3   (674.0, 837.0]  43.910000 -92.496666  726440-14925     0.764777   3.3
# 4   (438.0, 562.0]  42.212502 -83.353333  725370-94847     2.759307   9.4
#
#    WIND_SPD  PRECIP_1H CLIMATE_SEVERITY_IDX
# 0       6.2        0.0                    0
# 1       3.1        0.0                    0
# 2       6.7        0.0                    0
# 3       7.2        0.0                    0
# 4       3.1        0.0                    0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 1. Verificar filas, columnas y tipos

# %%
df.shape, df.dtypes
# Out:
# ((35669175, 25),
#  YEAR                             int16
#  MONTH                             int8
#  DAY_OF_MONTH                      int8
#  DAY_OF_WEEK                       int8
#  FL_DATE                 datetime64[ns]
#  OP_UNIQUE_CARRIER             category
#  ORIGIN                        category
#  ORIGIN_CITY_NAME              category
#  DEST                          category
#  DEST_CITY_NAME                category
#  CRS_DEP_TIME                     int16
#  DEP_DELAY                      float32
#  DEP_DEL15                         int8
#  DISTANCE                       float32
#  DEP_HOUR                          int8
#  sched_minute_of_day              int16
#  distance_bin                  category
#  LATITUDE                       float32
#  LONGITUDE                      float32
#  STATION_KEY                     object
#  DIST_MET_KM                    float32
#  TEMP                           float32
#  WIND_SPD                       float32
#  PRECIP_1H                      float32
#  CLIMATE_SEVERITY_IDX              int8
#  dtype: object)

# %% [markdown]
# ## 2. Analizar nulos y nulos encubiertos
# Nulos encubiertos: strings vacias, 'NA', 'N/A', 'NULL', 'null', 'None', 'nan'.

# %%
null_summary = df.isna().mean().sort_values(ascending=False)
null_summary.head(20)
# Out:
# YEAR                   0.0
# MONTH                  0.0
# DAY_OF_MONTH           0.0
# DAY_OF_WEEK            0.0
# FL_DATE                0.0
# OP_UNIQUE_CARRIER      0.0
# ORIGIN                 0.0
# ORIGIN_CITY_NAME       0.0
# DEST                   0.0
# DEST_CITY_NAME         0.0
# CRS_DEP_TIME           0.0
# DEP_DELAY              0.0
# DEP_DEL15              0.0
# DISTANCE               0.0
# DEP_HOUR               0.0
# sched_minute_of_day    0.0
# distance_bin           0.0
# LATITUDE               0.0
# LONGITUDE              0.0
# STATION_KEY            0.0
# dtype: float64

# %%
encubiertos = ['','NA','N/A','NULL','null','None','nan']
obj_cols = df.select_dtypes(include=['object','string']).columns
masked = {}
for col in obj_cols:
    masked[col] = df[col].isin(encubiertos).mean()
pd.Series(masked).sort_values(ascending=False).head(20)
# Out:
# STATION_KEY    0.0
# dtype: float64

# %% [markdown]
# ## 3. Analizar rangos y valores fuera de dominio
# Definir rangos esperados por dominio y verificar outliers basicos.

# %%
df.describe(include='all').T
# Out:
#                            count unique             top     freq  \
# YEAR                  35669175.0    NaN             NaN      NaN
# MONTH                 35669175.0    NaN             NaN      NaN
# DAY_OF_MONTH          35669175.0    NaN             NaN      NaN
# DAY_OF_WEEK           35669175.0    NaN             NaN      NaN
# FL_DATE                 35669175    NaN             NaN      NaN
# OP_UNIQUE_CARRIER       35669175     18              WN  7035589
# ORIGIN                  35669175    384             ATL  1767701
# ORIGIN_CITY_NAME        35669175    377     Chicago, IL  1841011
# DEST                    35669175    385             ATL  1767579
# DEST_CITY_NAME          35669175    378     Chicago, IL  1838919
# CRS_DEP_TIME          35669175.0    NaN             NaN      NaN
# DEP_DELAY             35669175.0    NaN             NaN      NaN
# DEP_DEL15             35669175.0    NaN             NaN      NaN
# DISTANCE              35669175.0    NaN             NaN      NaN
# DEP_HOUR              35669175.0    NaN             NaN      NaN
# sched_minute_of_day   35669175.0    NaN             NaN      NaN
# distance_bin            35669175     10  (228.0, 337.0]  3654749
# LATITUDE              35669175.0    NaN             NaN      NaN
# LONGITUDE             35669175.0    NaN             NaN      NaN
# STATION_KEY             35669175    384    722190-13874  1767701
# DIST_MET_KM           35669175.0    NaN             NaN      NaN
# TEMP                  35669175.0    NaN             NaN      NaN
# WIND_SPD              35669175.0    NaN             NaN      NaN
# PRECIP_1H             35669175.0    NaN             NaN      NaN
# CLIMATE_SEVERITY_IDX  35669175.0    NaN             NaN      NaN
#
#                                                mean                  min  \
# YEAR                                    2022.601322               2020.0
# MONTH                                      6.366319                  1.0
# DAY_OF_MONTH                              15.741241                  1.0
# DAY_OF_WEEK                                3.990993                  1.0
# FL_DATE               2023-02-01 21:46:22.546138880  2020-01-01 00:00:00
# OP_UNIQUE_CARRIER                               NaN                  NaN
# ORIGIN                                          NaN                  NaN
# ORIGIN_CITY_NAME                                NaN                  NaN
# DEST                                            NaN                  NaN
# DEST_CITY_NAME                                  NaN                  NaN
# CRS_DEP_TIME                            1325.141295                  1.0
# DEP_DELAY                                 10.799014               -128.0
# DEP_DEL15                                  0.188807                  0.0
# DISTANCE                                 823.718079                 11.0
# DEP_HOUR                                  12.982243                  0.0
# sched_minute_of_day                      805.851595                  1.0
# distance_bin                                    NaN                  NaN
# LATITUDE                                  36.643578           -14.331667
# LONGITUDE                                -95.068283          -176.645828
# STATION_KEY                                     NaN                  NaN
# DIST_MET_KM                                1.344856             0.022492
# TEMP                                       16.15229                -47.0
# WIND_SPD                                   3.547003                  0.0
# PRECIP_1H                                  0.086991                 -0.1
# CLIMATE_SEVERITY_IDX                       0.225797                  0.0
#
#                                       25%                  50%  \
# YEAR                               2021.0               2023.0
# MONTH                                 3.0                  6.0
# DAY_OF_MONTH                          8.0                 16.0
# DAY_OF_WEEK                           2.0                  4.0
# FL_DATE               2021-10-16 00:00:00  2023-03-01 00:00:00
# OP_UNIQUE_CARRIER                     NaN                  NaN
# ORIGIN                                NaN                  NaN
# ORIGIN_CITY_NAME                      NaN                  NaN
# DEST                                  NaN                  NaN
# DEST_CITY_NAME                        NaN                  NaN
# CRS_DEP_TIME                        910.0               1317.0
# DEP_DELAY                            -6.0                 -2.0
# DEP_DEL15                             0.0                  0.0
# DISTANCE                            392.0                674.0
# DEP_HOUR                              9.0                 13.0
# sched_minute_of_day                 550.0                797.0
# distance_bin                          NaN                  NaN
# LATITUDE                        32.896946            36.894722
# LONGITUDE                     -111.968887           -88.242775
# STATION_KEY                           NaN                  NaN
# DIST_MET_KM                       0.66173             1.237849
# TEMP                                  9.4            17.200001
# WIND_SPD                              2.1                  3.1
# PRECIP_1H                             0.0                  0.0
# CLIMATE_SEVERITY_IDX                  0.0                  0.0
#
#                                       75%                  max         std
# YEAR                               2024.0               2025.0    1.601984
# MONTH                                 9.0                 12.0    3.371166
# DAY_OF_MONTH                         23.0                 31.0      8.7699
# DAY_OF_WEEK                           6.0                  7.0    2.005924
# FL_DATE               2024-06-20 00:00:00  2025-09-30 00:00:00         NaN
# OP_UNIQUE_CARRIER                     NaN                  NaN         NaN
# ORIGIN                                NaN                  NaN         NaN
# ORIGIN_CITY_NAME                      NaN                  NaN         NaN
# DEST                                  NaN                  NaN         NaN
# DEST_CITY_NAME                        NaN                  NaN         NaN
# CRS_DEP_TIME                       1730.0               2400.0  486.858698
# DEP_DELAY                             7.0               4413.0   52.025177
# DEP_DEL15                             0.0                  1.0    0.391355
# DISTANCE                           1061.0               5812.0  592.630432
# DEP_HOUR                             17.0                 24.0    4.841241
# sched_minute_of_day                1050.0               1440.0  293.429743
# distance_bin                          NaN                  NaN         NaN
# LATITUDE                        40.777222            71.285004    6.053916
# LONGITUDE                      -80.951111           145.729996    18.56809
# STATION_KEY                           NaN                  NaN         NaN
# DIST_MET_KM                      1.782804            31.538223    0.909714
# TEMP                                 23.9                 50.0   10.110088
# WIND_SPD                              4.6            50.400002    2.343893
# PRECIP_1H                             0.0            97.699997    0.785251
# CLIMATE_SEVERITY_IDX                  0.0                  2.0    0.555189

# %% [markdown]
# ## 4. Analizar continuidad temporal
# Verificar huecos por fecha en la ventana disponible.

# %%
# Ajustar columna de fecha si el nombre difiere
fecha_col = None
for c in df.columns:
    if 'fecha' in c.lower() or 'date' in c.lower():
        fecha_col = c
        break
fecha_col
# Out:
# 'FL_DATE'

# %%
if fecha_col:
    fechas = pd.to_datetime(df[fecha_col], errors='coerce')
    fechas_dt = fechas.dropna().dt.date
    rango = pd.date_range(fechas_dt.min(), fechas_dt.max(), freq='D')
    presentes = pd.Series(fechas_dt.unique())
    faltantes = set(rango.date) - set(presentes)
    len(faltantes)

# %% [markdown]
# ## 5. Identificar fuga de informacion
# Revisar columnas que puedan contener informacion posterior al despegue.

# %%
sospechosas = [c for c in df.columns if any(k in c.lower() for k in ['delay','delayed','aterr','arr','dep_time','actual','real'])]
sospechosas
# Out:
# ['OP_UNIQUE_CARRIER', 'CRS_DEP_TIME', 'DEP_DELAY']

# %% [markdown]
# ## 6. Analizar distribucion del target (desbalance)

# %%
target_col = 'DEP_DEL15'
df[target_col].value_counts(dropna=False)
# Out:
# DEP_DEL15
# 0    28934579
# 1     6734596
# Name: count, dtype: int64
